# %%
import numpy as np
import pandas as pd

population_census = pd.read_csv("../datasets/US_Census_Population_2022.csv")
population_census.head()
# Out:
#                  GEO_ID                                        NAME  \
# 0             Geography                        Geographic Area Name
# 1   0600000US4820191835           Houston CCD, Harris County, Texas
# 2  1400000US48201100001  Census Tract 1000.01; Harris County; Texas
# 3  1400000US48201210400     Census Tract 2104; Harris County; Texas
# 4  1400000US48201210500     Census Tract 2105; Harris County; Texas
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                  3458465
# 2                                     5256
# 3                                     3983
# 4                                     4711
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                           11390
# 2                                             526
# 3                                             719
# ...
